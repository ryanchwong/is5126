# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import statistics as st 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, plot_confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler, RobustScaler
from sklearn.compose import make_column_selector
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RepeatedStratifiedKFold
from xgboost.sklearn import XGBRegressor
import lightgbm as lgb
from sklearn.ensemble import StackingRegressor
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_squared_error
from math import sqrt
import seaborn as sns

# %% [markdown]
# # EDA

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %% [markdown]
# #### planning_area & subzone NA value in test dataset

# %%
emptyPA = test[test['planning_area'].isna()]
emptyPA['address'].unique()
# Out:
# array(['1 tessensohn road', '38 lorong 32 geylang', '17 farrer drive',
#        '5 jalan mutiara'], dtype=object)

# %%
missingPA = pd.read_csv('auxiliary-data/missingPAdata.csv')
missingPA.head()
# Out:
#                 address planning_area     subzone
# 0     1 tessensohn road       kallang   boon keng
# 1  38 lorong 32 geylang       geyland    aljunied
# 2       15 farrer drive       tanglin  chatsworth
# 3       17 farrer drive       tanglin  chatsworth
# 4       5 jalan mutiara       tanglin      nassim

# %%
s = missingPA.set_index('address')['planning_area']
test['planning_area']=test['planning_area'].fillna(test['address'].map(s))

# %%
s = missingPA.set_index('address')['subzone']
test['subzone']=test['planning_area'].fillna(test['subzone'].map(s))

# %%
test.count()
# Out:
# listing_id              6966
# title                   6966
# address                 6964
# property_name           6966
# property_type           6966
# tenure                  6329
# built_year              6608
# num_beds                6931
# num_baths               6817
# size_sqft               6966
# floor_level             1156
# furnishing              6966
# available_unit_types    6446
# total_num_units         5066
# property_details_url    6966
# lat                     6966
# lng                     6966
# elevation               6966
# subzone                 6966
# planning_area           6966
# dtype: int64

# %% [markdown]
# #### planning & subzone in train dataset

# %%
data = train[train['planning_area'].isna()]
data['address'].unique()
# Out:
# array(['1 tessensohn road', '15 farrer drive', '17 farrer drive',
#        '38 lorong 32 geylang', '5 jalan mutiara'], dtype=object)

# %%
s = missingPA.set_index('address')['planning_area']
train['planning_area']=train['planning_area'].fillna(train['address'].map(s))

# %%
s = missingPA.set_index('address')['subzone']
train['subzone']=train['planning_area'].fillna(train['subzone'].map(s))

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# ### Remove listing_id
# #### listing_id is all unique without duplicates

# %%
train = train.drop(columns=['listing_id', 'property_details_url', 'elevation','property_name','address','title'])
test = test.drop(columns=['listing_id', 'property_details_url', 'elevation','property_name','address','title'])

# train = train.drop(columns=['property_details_url', 'elevation','property_name','address','title'])

# %%
train.describe()
# Out:
#          built_year      num_beds     num_baths     size_sqft  \
# count  19332.000000  20174.000000  19820.000000  2.025400e+04
# mean    2010.833695      3.122931      2.643542  1.854364e+03
# std       15.822803      1.281658      1.473835  1.354343e+04
# min     1963.000000      1.000000      1.000000  0.000000e+00
# 25%     2000.000000      2.000000      2.000000  8.070000e+02
# 50%     2017.000000      3.000000      2.000000  1.119000e+03
# 75%     2023.000000      4.000000      3.000000  1.528000e+03
# max     2028.000000     10.000000     10.000000  1.496000e+06
#
#        total_num_units           lat           lng         price
# count     14602.000000  20254.000000  20254.000000  2.025400e+04
# mean        376.253938      1.434282    103.855356  5.228263e+06
# std         346.882474      1.558472      3.593441  2.779748e+08
# min           4.000000      1.239621    -77.065364  0.000000e+00
# 25%         106.000000      1.307329    103.806576  8.190000e+05
# 50%         296.000000      1.329266    103.841552  1.680000e+06
# 75%         561.000000      1.372461    103.881514  3.242400e+06
# max        2612.000000     69.486768    121.023232  3.924243e+10

# %% [markdown]
# ### Adding Distances

# %% [markdown]
# #### Add distance to commericial centres

# %%
ccdistance = pd.read_csv('auxiliary-data/sg-commerical-centres.csv')

# %%
# vectorized haversine function
def haversine_np(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)

    All args must be of equal length.    

    """
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    return km

# %%
# train['cc_distance'] = haversine_np(train['lng'], train['lat'], ccdistance['lng'], ccdistance['lat'])
expected_result = pd.merge(train, ccdistance, on = 'planning_area')
expected_result.head()
train['cc_distance'] = haversine_np(train['lng'], train['lat'], expected_result['lng_y'], expected_result['lat_y'])

# train['cc_distance'] = haversine_np(train['lng'], train['lat'], ccdistance['lng'], ccdistance['lat'])
expected_result = pd.merge(test, ccdistance, on = 'planning_area')
expected_result.head()
test['cc_distance'] = haversine_np(test['lng'], test['lat'], expected_result['lng_y'], expected_result['lat_y'])

# %%
ccdistancemean = train['cc_distance'].median()
train['cc_distance']=train['cc_distance'].fillna(ccdistancemean)

ccdistancemean = test['cc_distance'].median()
test['cc_distance']=test['cc_distance'].fillna(ccdistancemean)

# %% [markdown]
# #### Add distance to mrt stations

# %%
# using long and lat
mrtdistance = pd.read_csv('auxiliary-data/sg-mrt-stations.csv')
expected_result = pd.merge(train, mrtdistance, on = 'planning_area')
train['mrt_distance'] = haversine_np(train['lng'], train['lat'], expected_result['lng_y'], expected_result['lat_y'])


# using long and lat
mrtdistance = pd.read_csv('auxiliary-data/sg-mrt-stations.csv')
expected_result = pd.merge(test, mrtdistance, on = 'planning_area')
test['mrt_distance'] = haversine_np(test['lng'], test['lat'], expected_result['lng_y'], expected_result['lat_y'])

# %%
mrtdistancemedian = train['mrt_distance'].median()
train['mrt_distance']=train['mrt_distance'].fillna(mrtdistancemedian)

mrtdistancemedian = test['mrt_distance'].median()
test['mrt_distance']=test['mrt_distance'].fillna(mrtdistancemedian)

# %% [markdown]
# #### Add distance to primary school

# %%
# using long and lat
primaryschooldistance = pd.read_csv('auxiliary-data/sg-primary-schools.csv')
expected_result = pd.merge(train, primaryschooldistance, on = 'planning_area')
train['primary_school_distance'] = haversine_np(train['lng'], train['lat'], expected_result['lng_y'], expected_result['lat_y'])

# using long and lat
primaryschooldistance = pd.read_csv('auxiliary-data/sg-primary-schools.csv')
expected_result = pd.merge(test, primaryschooldistance, on = 'planning_area')
test['primary_school_distance'] = haversine_np(test['lng'], test['lat'], expected_result['lng_y'], expected_result['lat_y'])

# %%
pschoolmedian = train['primary_school_distance'].median()
train['primary_school_distance'] = train['primary_school_distance'].fillna(pschoolmedian)

pschoolmedian = test['primary_school_distance'].median()
test['primary_school_distance'] = test['primary_school_distance'].fillna(pschoolmedian)

# %% [markdown]
# #### Add distance to secondary school

# %%
# using long and lat
secschooldistance = pd.read_csv('auxiliary-data/sg-secondary-schools.csv')
expected_result = pd.merge(train, secschooldistance, on = 'planning_area')
train['secondary_school_distance'] = haversine_np(train['lng'], train['lat'], expected_result['lng_y'], expected_result['lat_y'])

# using long and lat
secschooldistance = pd.read_csv('auxiliary-data/sg-secondary-schools.csv')
expected_result = pd.merge(test, secschooldistance, on = 'planning_area')
test['secondary_school_distance'] = haversine_np(test['lng'], test['lat'], expected_result['lng_y'], expected_result['lat_y'])

# %%
sschooldistance = train['secondary_school_distance'].median()
train['secondary_school_distance'] = train['secondary_school_distance'].fillna(sschooldistance)

sschooldistance = test['secondary_school_distance'].median()
test['secondary_school_distance'] = test['secondary_school_distance'].fillna(sschooldistance)

# %% [markdown]
# #### Add distance to shopping malls

# %%
# using long and lat
shop_distance = pd.read_csv('auxiliary-data/sg-shopping-malls.csv')
expected_result = pd.merge(train, secschooldistance, on = 'planning_area')
train['shop_distance'] = haversine_np(train['lng'], train['lat'], expected_result['lng_y'], expected_result['lat_y'])

# using long and lat
shop_distance = pd.read_csv('auxiliary-data/sg-shopping-malls.csv')
expected_result = pd.merge(test, secschooldistance, on = 'planning_area')
test['shop_distance'] = haversine_np(test['lng'], test['lat'], expected_result['lng_y'], expected_result['lat_y'])

# %%
sdistancemedian = train['shop_distance'].median()
train['shop_distance'] = train['shop_distance'].fillna(sdistancemedian)

sdistancemedian = test['shop_distance'].median()
test['shop_distance'] = test['shop_distance'].fillna(sdistancemedian)

# %%
train.head()
# Out:
#   property_type             tenure  built_year  num_beds  num_baths  \
# 0   hdb 4 rooms                NaN      1988.0       3.0        2.0
# 1           hdb  99-year leasehold      1992.0       4.0        2.0
# 2         condo           freehold      2022.0       4.0        6.0
# 3         Condo           freehold      2023.0       3.0        2.0
# 4         condo  99-year leasehold      2026.0       2.0        1.0
#
#    size_sqft floor_level   furnishing      available_unit_types  \
# 0       1115         NaN  unspecified                       NaN
# 1       1575         NaN  unspecified       1, 2, 3, 4, 5, 6 br
# 2       3070         low      partial     studio, 3, 4, 5, 6 br
# 3        958         NaN      partial     studio, 1, 2, 3, 4 br
# 4        732         NaN  unspecified  studio, 1, 2, 3, 4, 5 br
#
#    total_num_units       lat         lng        subzone  planning_area  \
# 0            116.0  1.414399  103.837196         yishun         yishun
# 1              NaN  1.372597  103.875625      serangoon      serangoon
# 2             56.0  1.298773  103.895798  marine parade  marine parade
# 3            638.0  1.312364  103.803271    bukit timah    bukit timah
# 4            351.0  1.273959  103.843635  downtown core  downtown core
#
#        price  cc_distance  mrt_distance  primary_school_distance  \
# 0   514500.0     8.027727      1.689357                 5.178683
# 1   995400.0     2.400374      6.871207                 8.310177
# 2  8485000.0     6.389766     13.983476                 9.485153
# 3  2626000.0     8.802339     13.479646                 3.290085
# 4  1764000.0     9.160635     15.981982                13.818954
#
#    secondary_school_distance  shop_distance
# 0                   2.538065       2.538065
# 1                   6.710202       6.710202
# 2                  15.197137      15.197137
# 3                  12.950660      12.950660
# 4                  17.977600      17.977600

# %% [markdown]
# ### lng & lat

# %%
train.head()
# Out:
#   property_type             tenure  built_year  num_beds  num_baths  \
# 0   hdb 4 rooms                NaN      1988.0       3.0        2.0
# 1           hdb  99-year leasehold      1992.0       4.0        2.0
# 2         condo           freehold      2022.0       4.0        6.0
# 3         Condo           freehold      2023.0       3.0        2.0
# 4         condo  99-year leasehold      2026.0       2.0        1.0
#
#    size_sqft floor_level   furnishing      available_unit_types  \
# 0       1115         NaN  unspecified                       NaN
# 1       1575         NaN  unspecified       1, 2, 3, 4, 5, 6 br
# 2       3070         low      partial     studio, 3, 4, 5, 6 br
# 3        958         NaN      partial     studio, 1, 2, 3, 4 br
# 4        732         NaN  unspecified  studio, 1, 2, 3, 4, 5 br
#
#    total_num_units       lat         lng        subzone  planning_area  \
# 0            116.0  1.414399  103.837196         yishun         yishun
# 1              NaN  1.372597  103.875625      serangoon      serangoon
# 2             56.0  1.298773  103.895798  marine parade  marine parade
# 3            638.0  1.312364  103.803271    bukit timah    bukit timah
# 4            351.0  1.273959  103.843635  downtown core  downtown core
#
#        price  cc_distance  mrt_distance  primary_school_distance  \
# 0   514500.0     8.027727      1.689357                 5.178683
# 1   995400.0     2.400374      6.871207                 8.310177
# 2  8485000.0     6.389766     13.983476                 9.485153
# 3  2626000.0     8.802339     13.479646                 3.290085
# 4  1764000.0     9.160635     15.981982                13.818954
#
#    secondary_school_distance  shop_distance
# 0                   2.538065       2.538065
# 1                   6.710202       6.710202
# 2                  15.197137      15.197137
# 3                  12.950660      12.950660
# 4                  17.977600      17.977600

# %%
train = train.drop(columns=['lat','lng'])

# %%
test = test.drop(columns=['lat','lng'])

# %% [markdown]
# ### Population

# %%
population = pd.read_csv('auxiliary-data/sg-subzones.csv')

# %%
expected_result = pd.merge(train, population, on = 'planning_area')
train['population'] = expected_result['population']
train['area_size'] = expected_result['area_size']

# %%
expected_result = pd.merge(test, population, on = 'planning_area')
test['population'] = expected_result['population']
test['area_size'] = expected_result['area_size']

# %%
train.head()
# Out:
#   property_type             tenure  built_year  num_beds  num_baths  \
# 0   hdb 4 rooms                NaN      1988.0       3.0        2.0
# 1           hdb  99-year leasehold      1992.0       4.0        2.0
# 2         condo           freehold      2022.0       4.0        6.0
# 3         Condo           freehold      2023.0       3.0        2.0
# 4         condo  99-year leasehold      2026.0       2.0        1.0
#
#    size_sqft floor_level   furnishing      available_unit_types  \
# 0       1115         NaN  unspecified                       NaN
# 1       1575         NaN  unspecified       1, 2, 3, 4, 5, 6 br
# 2       3070         low      partial     studio, 3, 4, 5, 6 br
# 3        958         NaN      partial     studio, 1, 2, 3, 4 br
# 4        732         NaN  unspecified  studio, 1, 2, 3, 4, 5 br
#
#    total_num_units        subzone  planning_area      price  cc_distance  \
# 0            116.0         yishun         yishun   514500.0     8.027727
# 1              NaN      serangoon      serangoon   995400.0     2.400374
# 2             56.0  marine parade  marine parade  8485000.0     6.389766
# 3            638.0    bukit timah    bukit timah  2626000.0     8.802339
# 4            351.0  downtown core  downtown core  1764000.0     9.160635
#
#    mrt_distance  primary_school_distance  secondary_school_distance  \
# 0      1.689357                 5.178683                   2.538065
# 1      6.871207                 8.310177                   6.710202
# 2     13.983476                 9.485153                  15.197137
# 3     13.479646                 3.290085                  12.950660
# 4     15.981982                13.818954                  17.977600
#
#    shop_distance  population  area_size
# 0       2.538065       10250     1.4329
# 1       6.710202       18660     8.4055
# 2      15.197137         890     2.2068
# 3      12.950660       28000     1.5110
# 4      17.977600        4370     2.2092

# %% [markdown]
# ### Property Type cleaning

# %%
#Change all to uppercase
train['property_type']=train['property_type'].str.upper()

#Change all to uppercase
test['property_type']=test['property_type'].str.upper()

# %%
#for regression only
# from sklearn import preprocessing
# le = preprocessing.LabelEncoder()
# le.fit(train['property_type'])
# train['property_type']=le.transform(train['property_type'])

# test['property_type']=le.transform(test['property_type'])

# one hot endcoding
# pd.get_dummies(train.property_type, prefix='property')

# %% [markdown]
# ### Tenure

# %%
train['tenure'] = train['tenure'].replace(
    [
    '99-year leasehold',
    '110-year leasehold',
    '103-year leasehold',
    '102-year leasehold',
    '100-year leasehold',
    ],
    '99-year leasehold'
)

train['tenure'] = train['tenure'].replace(
    [
    '946-year leasehold',
    '999-year leasehold',
    '956-year leasehold',
    '929-year leasehold',
    '947-year leasehold',
    ],
    '999-year leasehold'
)



test['tenure'] = test['tenure'].replace(
    [
    '99-year leasehold',
    '110-year leasehold',
    '103-year leasehold',
    '102-year leasehold',
    '100-year leasehold',
    ],
    '99-year leasehold'
)

test['tenure'] = test['tenure'].replace(
    [
    '946-year leasehold',
    '999-year leasehold',
    '956-year leasehold',
    '929-year leasehold',
    '947-year leasehold',
    ],
    '999-year leasehold'
)

# %%
test['tenure'] = test['tenure'].fillna('99-year leasehold')

# %%
train['tenure'] = train['tenure'].fillna('99-year leasehold')

# %%
## Remove NA 
train = train.dropna(subset=['tenure'])

## Remove NA 
test['tenure'] = test['tenure'].fillna('99-year leasehold')

# %%
#for regression only

# from sklearn import preprocessing
# tenurepp = preprocessing.LabelEncoder()
# tenurepp.fit(train['tenure'])
# train['tenure']=tenurepp.transform(train['tenure'])

# test['tenure']=tenurepp.transform(test['tenure'])

# %% [markdown]
# ### Funishing

# %%
#Assume not specified and na as unfurnished 
train['furnishing'] = train['furnishing'].replace(
    [
    'na',
    'unspecified',
    ],
    'unfurnished'
)

#Assume not specified and na as unfurnished 
test['furnishing'] = test['furnishing'].replace(
    [
    'na',
    'unspecified',
    ],
    'unfurnished'
)

# %%
#for regression only

# from sklearn import preprocessing
# furnishing = preprocessing.LabelEncoder()
# furnishing.fit(train['furnishing'])
# train['furnishing']=furnishing.transform(train['furnishing'])

# test['furnishing']=furnishing.transform(test['furnishing'])

# %% [markdown]
# ### floor_level

# %%
# Too few data for floor level, we should just take out the column
train = train.drop(columns='floor_level')

# Too few data for floor level, we should just take out the column
test = test.drop(columns='floor_level')

# %% [markdown]
# ### total_num_units

# %%
mediantotalunit = train['total_num_units'].median()
train['total_num_units'].fillna(mediantotalunit, inplace=True)

mediantotalunit = test['total_num_units'].median()
test['total_num_units'].fillna(mediantotalunit, inplace=True)

# %% [markdown]
# ### build year

# %%
avgbuildyear = round(train['built_year'].median(),0)
train['built_year'] = train['built_year'].fillna(avgbuildyear)

avgbuildyear = round(test['built_year'].median(),0)
test['built_year'] = test['built_year'].fillna(avgbuildyear)

# %% [markdown]
# ### num_baths

# %%
train.head()
# Out:
#   property_type             tenure  built_year  num_beds  num_baths  \
# 0   HDB 4 ROOMS  99-year leasehold      1988.0       3.0        2.0
# 1           HDB  99-year leasehold      1992.0       4.0        2.0
# 2         CONDO           freehold      2022.0       4.0        6.0
# 3         CONDO           freehold      2023.0       3.0        2.0
# 4         CONDO  99-year leasehold      2026.0       2.0        1.0
#
#    size_sqft   furnishing      available_unit_types  total_num_units  \
# 0       1115  unfurnished                       NaN            116.0
# 1       1575  unfurnished       1, 2, 3, 4, 5, 6 br            296.0
# 2       3070      partial     studio, 3, 4, 5, 6 br             56.0
# 3        958      partial     studio, 1, 2, 3, 4 br            638.0
# 4        732  unfurnished  studio, 1, 2, 3, 4, 5 br            351.0
#
#          subzone  planning_area      price  cc_distance  mrt_distance  \
# 0         yishun         yishun   514500.0     8.027727      1.689357
# 1      serangoon      serangoon   995400.0     2.400374      6.871207
# 2  marine parade  marine parade  8485000.0     6.389766     13.983476
# 3    bukit timah    bukit timah  2626000.0     8.802339     13.479646
# 4  downtown core  downtown core  1764000.0     9.160635     15.981982
#
#    primary_school_distance  secondary_school_distance  shop_distance  \
# 0                 5.178683                   2.538065       2.538065
# 1                 8.310177                   6.710202       6.710202
# 2                 9.485153                  15.197137      15.197137
# 3                 3.290085                  12.950660      12.950660
# 4                13.818954                  17.977600      17.977600
#
#    population  area_size
# 0       10250     1.4329
# 1       18660     8.4055
# 2         890     2.2068
# 3       28000     1.5110
# 4        4370     2.2092

# %%
train.dtypes
# Out:
# property_type                 object
# tenure                        object
# built_year                   float64
# num_beds                     float64
# num_baths                    float64
# size_sqft                      int64
# furnishing                    object
# available_unit_types          object
# total_num_units              float64
# subzone                       object
# planning_area                 object
# price                        float64
# cc_distance                  float64
# mrt_distance                 float64
# primary_school_distance      float64
# secondary_school_distance    float64
# shop_distance                float64
# population                     int64
# area_size                    float64
# dtype: object

# %%
a = train[train['num_baths'].isna()]
a[a['num_beds'].isna()]
# Out:
#       property_type             tenure  built_year  num_beds  num_baths  \
# 3713       BUNGALOW           freehold      1990.0       NaN        NaN
# 4691          CONDO  99-year leasehold      2023.0       NaN        NaN
# 4939            HDB  99-year leasehold      1980.0       NaN        NaN
# 5002            HDB  99-year leasehold      2004.0       NaN        NaN
# 11500           HDB  99-year leasehold      1985.0       NaN        NaN
#
#        size_sqft   furnishing         available_unit_types  total_num_units  \
# 3713        9594  unfurnished     studio, 1, 4, 5, 6, 7 br            296.0
# 4691         431  unfurnished  studio, 1, 2, 3, 4, 5, 8 br            774.0
# 4939         731  unfurnished                          NaN            112.0
# 5002        1184  unfurnished                          NaN             90.0
# 11500        786  unfurnished           studio, 2, 3, 4 br            296.0
#
#            subzone planning_area       price  cc_distance  mrt_distance  \
# 3713        novena        novena  16275000.0     5.668353      5.872226
# 4691        outram        outram   1222200.0     5.825357      8.355056
# 4939         bedok         bedok    367500.0    15.229001      7.025831
# 5002       punggol       punggol    669900.0    16.664632      6.751215
# 11500  bukit batok   bukit batok    409500.0     8.707527      4.914059
#
#        primary_school_distance  secondary_school_distance  shop_distance  \
# 3713                  6.905858                  11.134265      11.134265
# 4691                 11.798265                  15.372730      15.372730
# 4939                  8.583307                  13.354867      13.354867
# 5002                  7.404180                   7.477411       7.477411
# 11500                 6.279880                  18.454836      18.454836
#
#        population  area_size
# 3713         2620     0.4364
# 4691          890     2.2068
# 4939        42240     1.3402
# 5002        42240     1.3402
# 11500       24760     1.0619

# %%
avgbath = train['num_baths'].median()
train['num_baths'] = train['num_baths'].fillna(avgbath)

avgbath = test['num_baths'].median()
test['num_baths'] = test['num_baths'].fillna(avgbath)

# %% [markdown]
# ### num_bedds

# %%
avgbed = train['num_beds'].median()
train['num_beds'] = train['num_beds'].fillna(avgbath)

avgbed = test['num_beds'].median()
test['num_beds'] = test['num_beds'].fillna(avgbath)

# %% [markdown]
# ### num_avaliable_units

# %%
numavaunittypes = train.available_unit_types.str.count(',') + 1
train['available_unit_types'] = numavaunittypes

# %%
avg_ava_units = train['available_unit_types'].median()
train['available_unit_types'] = train['available_unit_types'].fillna(avg_ava_units)

# %%
numavaunittypes = test.available_unit_types.str.count(',') +1
test['available_unit_types'] = numavaunittypes

avg_ava_units = test['available_unit_types'].median()
test['available_unit_types'] = test['available_unit_types'].fillna(avg_ava_units)

# %%
train.dtypes
# Out:
# property_type                 object
# tenure                        object
# built_year                   float64
# num_beds                     float64
# num_baths                    float64
# size_sqft                      int64
# furnishing                    object
# available_unit_types         float64
# total_num_units              float64
# subzone                       object
# planning_area                 object
# price                        float64
# cc_distance                  float64
# mrt_distance                 float64
# primary_school_distance      float64
# secondary_school_distance    float64
# shop_distance                float64
# population                     int64
# area_size                    float64
# dtype: object

# %% [markdown]
# ### Subzone & planning zone Encoding

# %%
#regression 

# pa = train['planning_area'] + test['planning_area']
# pa = pa.dropna().drop_duplicates().unique()
# pa = pd.DataFrame(pa)
# pa.count()

# %%
# a = train['planning_area'].drop_duplicates()
# b = test['planning_area'].drop_duplicates()
# c = pd.concat([a, b]).dropna()
# c = c.drop_duplicates()

# %%
# #for regression only

# from sklearn import preprocessing
# planningzone = preprocessing.LabelEncoder()
# planningzone.fit(c)

# train = train.dropna()
# train['planning_area']=planningzone.transform(train['planning_area'])

# %%
# mostfreq = test['planning_area'].mode()
# mostfreq
# test['planning_area'] = test['planning_area'].fillna('bukit timah')
# test['planning_area']=planningzone.transform(test['planning_area'])

# %% [markdown]
# ### size_sqft

# %%
train.head()
# Out:
#   property_type             tenure  built_year  num_beds  num_baths  \
# 0   HDB 4 ROOMS  99-year leasehold      1988.0       3.0        2.0
# 1           HDB  99-year leasehold      1992.0       4.0        2.0
# 2         CONDO           freehold      2022.0       4.0        6.0
# 3         CONDO           freehold      2023.0       3.0        2.0
# 4         CONDO  99-year leasehold      2026.0       2.0        1.0
#
#    size_sqft   furnishing  available_unit_types  total_num_units  \
# 0       1115  unfurnished                   5.0            116.0
# 1       1575  unfurnished                   6.0            296.0
# 2       3070      partial                   5.0             56.0
# 3        958      partial                   5.0            638.0
# 4        732  unfurnished                   6.0            351.0
#
#          subzone  planning_area      price  cc_distance  mrt_distance  \
# 0         yishun         yishun   514500.0     8.027727      1.689357
# 1      serangoon      serangoon   995400.0     2.400374      6.871207
# 2  marine parade  marine parade  8485000.0     6.389766     13.983476
# 3    bukit timah    bukit timah  2626000.0     8.802339     13.479646
# 4  downtown core  downtown core  1764000.0     9.160635     15.981982
#
#    primary_school_distance  secondary_school_distance  shop_distance  \
# 0                 5.178683                   2.538065       2.538065
# 1                 8.310177                   6.710202       6.710202
# 2                 9.485153                  15.197137      15.197137
# 3                 3.290085                  12.950660      12.950660
# 4                13.818954                  17.977600      17.977600
#
#    population  area_size
# 0       10250     1.4329
# 1       18660     8.4055
# 2         890     2.2068
# 3       28000     1.5110
# 4        4370     2.2092

# %%
train = train[train['size_sqft'] != 0]

# %% [markdown]
# #### price

# %% [markdown]
# Remove price which is 0

# %%
train = train[train['price'] != 0]

# %% [markdown]
# ## Change Types

# %%
train['built_year'] = train['built_year'].astype(int)
train['num_beds'] = train['num_beds'].astype(int)
train['num_baths'] = train['num_baths'].astype(int)
train['available_unit_types'] = train['available_unit_types'].astype(int)
train['total_num_units'] = train['total_num_units'].astype(int)

# %%
train.count()
# Out:
# property_type                20153
# tenure                       20153
# built_year                   20153
# num_beds                     20153
# num_baths                    20153
# size_sqft                    20153
# furnishing                   20153
# available_unit_types         20153
# total_num_units              20153
# subzone                      20153
# planning_area                20153
# price                        20153
# cc_distance                  20153
# mrt_distance                 20153
# primary_school_distance      20153
# secondary_school_distance    20153
# shop_distance                20153
# population                   20153
# area_size                    20153
# dtype: int64

# %%
test['built_year'] = test['built_year'].astype(int)
test['num_beds'] = test['num_beds'].astype(int)
test['num_baths'] = test['num_baths'].astype(int)
test['available_unit_types'] = test['available_unit_types'].astype(int)
test['total_num_units'] = test['total_num_units'].astype(int)

# %%
test.count()
# Out:
# property_type                6966
# tenure                       6966
# built_year                   6966
# num_beds                     6966
# num_baths                    6966
# size_sqft                    6966
# furnishing                   6966
# available_unit_types         6966
# total_num_units              6966
# subzone                      6966
# planning_area                6966
# cc_distance                  6966
# mrt_distance                 6966
# primary_school_distance      6966
# secondary_school_distance    6966
# shop_distance                6966
# population                   6966
# area_size                    6966
# dtype: int64

# %% [markdown]
# ## Outlier Detection

# %% [markdown]
# #### Price

# %%
sns.distplot(train['price'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
train['price'] >= 200000
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 20249    True
# 20250    True
# 20251    True
# 20252    True
# 20253    True
# Name: price, Length: 20153, dtype: bool

# %% [markdown]
# #### Coorleation Matrix Before Outlier removal

# %%
# plt.figure(figsize=(14,8))
# sns.heatmap(train.corr())
# plt.show()

# %%
# plt.figure(figsize=(14,8))
# train.corr()['price'].sort_values()[:-1].plot(kind='bar')
# plt.show()

# %% [markdown]
# #### Isolation Forest on Price, Price per Sqft, cc_distance, mrt distance, primary school distance, secondary school distance, shop distance

# %%
train.head()
# Out:
#   property_type             tenure  built_year  num_beds  num_baths  \
# 0   HDB 4 ROOMS  99-year leasehold        1988         3          2
# 1           HDB  99-year leasehold        1992         4          2
# 2         CONDO           freehold        2022         4          6
# 3         CONDO           freehold        2023         3          2
# 4         CONDO  99-year leasehold        2026         2          1
#
#    size_sqft   furnishing  available_unit_types  total_num_units  \
# 0       1115  unfurnished                     5              116
# 1       1575  unfurnished                     6              296
# 2       3070      partial                     5               56
# 3        958      partial                     5              638
# 4        732  unfurnished                     6              351
#
#          subzone  planning_area      price  cc_distance  mrt_distance  \
# 0         yishun         yishun   514500.0     8.027727      1.689357
# 1      serangoon      serangoon   995400.0     2.400374      6.871207
# 2  marine parade  marine parade  8485000.0     6.389766     13.983476
# 3    bukit timah    bukit timah  2626000.0     8.802339     13.479646
# 4  downtown core  downtown core  1764000.0     9.160635     15.981982
#
#    primary_school_distance  secondary_school_distance  shop_distance  \
# 0                 5.178683                   2.538065       2.538065
# 1                 8.310177                   6.710202       6.710202
# 2                 9.485153                  15.197137      15.197137
# 3                 3.290085                  12.950660      12.950660
# 4                13.818954                  17.977600      17.977600
#
#    population  area_size
# 0       10250     1.4329
# 1       18660     8.4055
# 2         890     2.2068
# 3       28000     1.5110
# 4        4370     2.2092

# %%
outlierdata = train[['price','cc_distance','mrt_distance','primary_school_distance','secondary_school_distance','shop_distance']]

# %%
from sklearn.ensemble import IsolationForest
model=IsolationForest(max_samples='auto', contamination=float(0.1))
model.fit(outlierdata)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# IsolationForest(contamination=0.1)

# %%
train['scores_price']=model.decision_function(outlierdata)
train['anomaly_price']=model.predict(outlierdata)

# %%
anomaly=train.loc[train['anomaly_price']==-1]
anomaly_index=list(anomaly.index)
print(anomaly)
# Out:
#              property_type              tenure  built_year  num_beds  \
# 7                 BUNGALOW  999-year leasehold        2017         5
# 18                   CONDO   99-year leasehold        2017         4
# 23          TERRACED HOUSE   99-year leasehold        2017         5
# 30               APARTMENT            freehold        2023         3
# 35             HDB 4 ROOMS   99-year leasehold        2017         3
# ...                    ...                 ...         ...       ...
# 20205                CONDO   99-year leasehold        2023         1
# 20221             BUNGALOW   99-year leasehold        1977         5
# 20235                CONDO   99-year leasehold        2027         2
# 20236          HDB 5 ROOMS   99-year leasehold        1996         4
# 20241  SEMI-DETACHED HOUSE            freehold        2025         6
#
#        num_baths  size_sqft   furnishing  available_unit_types  \
# 7              6      11500  unfurnished                     6
# 18             7       6200  unfurnished                     6
# 23             6       7829  unfurnished                     1
# 30             3       1130  unfurnished                     7
# 35             2       1001  unfurnished                     2
# ...          ...        ...          ...                   ...
# 20205          1        485  unfurnished                     6
# 20221          4       5990  unfurnished                     6
# 20235          1        657  unfurnished                     4
# 20236          2       1302      partial                     5
# 20241          6       4717  unfurnished                     5
#
#        total_num_units        subzone  ...       price  cc_distance  \
# 7                  296    bukit timah  ...  15645000.0     9.805071
# 18                 510  downtown core  ...  19740000.0     8.598379
# 23                 296         novena  ...  11025000.0     5.139553
# 30                  58        kallang  ...   2671200.0  2382.541866
# 35                 588         yishun  ...    581700.0     8.656365
# ...                ...            ...  ...         ...          ...
# 20205             2203       tampines  ...   1039500.0    10.324064
# 20221              296      pasir ris  ...   6489000.0    10.324064
# 20235              158          bedok  ...   1379700.0    10.324064
# 20236               77       tampines  ...    669900.0    10.324064
# 20241                6  marine parade  ...   8059800.0    10.324064
#
#        mrt_distance  primary_school_distance  secondary_school_distance  \
# 7          9.927822                17.317227                  11.659117
# 18        16.974983                19.640107                  15.894268
# 23         8.647453                 4.589247                  12.296816
# 30      2380.370041              2386.393729                2379.896904
# 35         4.217853                15.117326                   0.325263
# ...             ...                      ...                        ...
# 20205     11.222257                 7.607177                  22.015472
# 20221     15.153852                18.841761                  22.274680
# 20235     10.223250                25.999032                  20.706548
# 20236     13.914053                29.371848                  24.710617
# 20241      5.028636                19.216688                  17.709094
#
#        shop_distance  population  area_size  scores_price  anomaly_price
# 7          11.659117       42240     1.3402     -0.011707             -1
# 18         15.894268       10250     1.4329     -0.068314             -1
# 23         12.296816        2620     0.4364     -0.003129             -1
# 30       2379.896904       28000     1.5110     -0.353325             -1
# 35          0.325263       53910     1.5178     -0.022082             -1
# ...              ...         ...        ...           ...            ...
# 20205      22.015472       21870     2.7733     -0.011365             -1
# 20221      22.274680       21870     2.7733     -0.062273             -1
# 20235      20.706548        5340     3.4685     -0.047112             -1
# 20236      24.710617       11020     1.2271     -0.114440             -1
# 20241      17.709094       10840     3.3872     -0.018462             -1
#
# [2016 rows x 21 columns]

# %%
train = train[train.anomaly_price != -1]

# %%
sns.displot(train['price'])

# %%
print("Skewness : %f" % train['price'].skew())
print("Kurtosis : %f" % train['price'].kurt())
# Out:
# Skewness : 2.141128
# Kurtosis : 5.665371

# %%
train.describe()
# Out:
#          built_year      num_beds     num_baths     size_sqft  \
# count  18137.000000  18137.000000  18137.000000  1.813700e+04
# mean    2011.458896      2.987374      2.461267  1.580256e+03
# std       15.557238      1.173711      1.270813  1.421397e+04
# min     1963.000000      1.000000      1.000000  6.500000e+01
# 25%     2002.000000      2.000000      2.000000  7.750000e+02
# 50%     2017.000000      3.000000      2.000000  1.076000e+03
# 75%     2023.000000      4.000000      3.000000  1.399000e+03
# max     2028.000000     10.000000     10.000000  1.496000e+06
#
#        available_unit_types  total_num_units         price   cc_distance  \
# count          18137.000000     18137.000000  1.813700e+04  18137.000000
# mean               4.686993       361.881348  2.298242e+06     10.393504
# std                1.665679       297.139575  2.161732e+06      4.684709
# min                1.000000         4.000000  2.508000e+05      0.166654
# 25%                4.000000       158.000000  8.169000e+05      7.080943
# 50%                5.000000       296.000000  1.585400e+06     10.324064
# 75%                6.000000       455.000000  2.927400e+06     13.012952
# max               10.000000      2612.000000  1.667400e+07     29.798731
#
#        mrt_distance  primary_school_distance  secondary_school_distance  \
# count  18137.000000             18137.000000               18137.000000
# mean       8.756814                11.061377                   9.643028
# std        4.541275                 5.208995                   4.306314
# min        0.027288                 0.163496                   0.269643
# 25%        5.085190                 7.165982                   6.176892
# 50%        8.305459                10.932052                   9.546461
# 75%       12.260248                14.821674                  13.163937
# max       22.877877                29.078982                  20.994975
#
#        shop_distance    population     area_size  scores_price  anomaly_price
# count   18137.000000  18137.000000  18137.000000  18137.000000        18137.0
# mean        9.643028  17094.232232      1.796510      0.066436            1.0
# std         4.306314  16241.571242      1.530318      0.027079            0.0
# min         0.269643      0.000000      0.436400      0.000004            1.0
# 25%         6.176892   5340.000000      1.061900      0.048130            1.0
# 50%         9.546461  10840.000000      1.432900      0.070233            1.0
# 75%        13.163937  24760.000000      2.206800      0.087563            1.0
# max        20.994975  60670.000000      8.405500      0.119860            1.0

# %%
from scipy import stats
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler


sns.distplot(train['price'], fit = norm)
fig = plt.figure()
res = stats.probplot(train['price'],plot = plt)
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
train = train.drop(columns='scores_price')
train = train.drop(columns='anomaly_price')

# %%
test.head()
# Out:
#   property_type             tenure  built_year  num_beds  num_baths  \
# 0         CONDO           freehold        2022         1          1
# 1         CONDO  99-year leasehold        2017         3          3
# 2         CONDO  99-year leasehold        2007         1          1
# 3           HDB  99-year leasehold        2017         3          2
# 4   HDB 4 ROOMS  99-year leasehold        1973         3          2
#
#    size_sqft   furnishing  available_unit_types  total_num_units  \
# 0        463  unfurnished                     6              250
# 1       1033  unfurnished                     6              463
# 2        570        fully                     4              646
# 3       1216  unfurnished                     5              968
# 4        936  unfurnished                     4              298
#
#          subzone  planning_area  cc_distance  mrt_distance  \
# 0      serangoon      serangoon     1.046868      0.960436
# 1      pasir ris      pasir ris     8.581574      9.346690
# 2         museum         museum     6.755363      6.710905
# 3  choa chu kang  choa chu kang    14.229296     14.293216
# 4      toa payoh      toa payoh     2.802424      2.077951
#
#    primary_school_distance  secondary_school_distance  shop_distance  \
# 0                13.993735                   1.853769       1.853769
# 1                13.709624                   8.403509       8.403509
# 2                 8.965840                   6.503082       6.503082
# 3                12.559347                  13.963584      13.963584
# 4                 6.903112                   3.079569       3.079569
#
#    population  area_size
# 0        8490     1.1801
# 1       14700     2.3307
# 2       24760     1.0619
# 3       36080     3.0232
# 4       15940     0.6847

# %%
train.head()
# Out:
#   property_type             tenure  built_year  num_beds  num_baths  \
# 0   HDB 4 ROOMS  99-year leasehold        1988         3          2
# 1           HDB  99-year leasehold        1992         4          2
# 2         CONDO           freehold        2022         4          6
# 3         CONDO           freehold        2023         3          2
# 4         CONDO  99-year leasehold        2026         2          1
#
#    size_sqft   furnishing  available_unit_types  total_num_units  \
# 0       1115  unfurnished                     5              116
# 1       1575  unfurnished                     6              296
# 2       3070      partial                     5               56
# 3        958      partial                     5              638
# 4        732  unfurnished                     6              351
#
#          subzone  planning_area      price  cc_distance  mrt_distance  \
# 0         yishun         yishun   514500.0     8.027727      1.689357
# 1      serangoon      serangoon   995400.0     2.400374      6.871207
# 2  marine parade  marine parade  8485000.0     6.389766     13.983476
# 3    bukit timah    bukit timah  2626000.0     8.802339     13.479646
# 4  downtown core  downtown core  1764000.0     9.160635     15.981982
#
#    primary_school_distance  secondary_school_distance  shop_distance  \
# 0                 5.178683                   2.538065       2.538065
# 1                 8.310177                   6.710202       6.710202
# 2                 9.485153                  15.197137      15.197137
# 3                 3.290085                  12.950660      12.950660
# 4                13.818954                  17.977600      17.977600
#
#    population  area_size
# 0       10250     1.4329
# 1       18660     8.4055
# 2         890     2.2068
# 3       28000     1.5110
# 4        4370     2.2092

# %% [markdown]
# ## Data Visualization after cleaning

# %%
# train['log_size_sqft'] = np.log(train['size_sqft'])
# plot_train = train.drop(columns=['size_sqft'])
# plot_train.hist(bins=50, figsize=(15, 10), grid=False, edgecolor='black')
# plt.tight_layout(pad=0, rect=[0, 0, 0.9, 0.9])
# plt.show()

# %% [markdown]
# #### Planning_area ~ price

# %%
# # Visualization
# fig, ax = plt.subplots(1,1, figsize=(12, 8), dpi=80)

# # Find the order
# my_order = train.groupby(by=["planning_area"])["log_price"].mean().sort_values(ascending=False).index

# box_plot = sns.boxplot(x = 'subzone',y = 'price',data = train, order=my_order)
# plt.ylabel('Price')
# plt.xlabel('planning area')
# plt.title('Planning Area housing price range comparison', fontsize=15, fontweight='bold', fontfamily='serif')

# ax = box_plot.axes

# lines = ax.get_lines()
# #categories = ax.get_xticks()
# ax.tick_params(axis='x', rotation=90)

# for s in ['top', 'left', 'right']:
#     ax.spines[s].set_visible(False)
# ax.grid(axis='y', linestyle='-', alpha=0.4) 

# box_plot.figure.tight_layout()

# #fig = box_plot.get_figure()

# %% [markdown]
# #### Coorelation Matrix

# %%
# plt.figure(figsize=(14,8))
# sns.heatmap(train.corr())
# plt.show()

# %%
# plt.figure(figsize=(14,8))
# train.corr()['price'].sort_values()[:-1].plot(kind='bar')
# plt.show()

# %% [markdown]
# #### Year Built ~ Price

# %%
# fig, axes = plt.subplots(figsize=(18,8))
# sns.scatterplot(x ='price', y= 'built_year', data=train)
# axes.set_title('Price vs Year Built')
# plt.show()

# %% [markdown]
# ### property_type ~ price

# %%
# # Violin plots for price distribution of each flat model

# fig = plt.figure(figsize=(12,7))
# p=sns.violinplot(x='property_type', y='log_price', data=train, width=1,
#                 order=train.groupby('property_type')['price'].median().sort_values().reset_index()['property_type'].tolist())
# p.set_xticklabels(p.get_xticklabels(), rotation=30, ha='right'), p.set_xlabel('property type', size=15)
# ylabels = ['{:,.0f}'.format(x) + 'K' for x in p.get_yticks()/1000]
# p.set_yticklabels(ylabels)
# p.set_ylabel('Resale Price SGD ($)', size=15)
# plt.show()

# %%
train.head()

# %% [markdown]
# #### Price ~ Distance

# %%
# p=sns.pairplot(train, x_vars=["cc_distance", "mrt_distance", "primary_school_distance", "secondary_school_distance", "shop_distance"], y_vars=["price"], height=3, aspect=1, kind="reg", plot_kws=dict(scatter_kws=dict(s=40)))
# axes=p.axes
# ylabels = ['{:,.0f}'.format(x) + 'K' for x in axes[0,0].get_yticks()/1000]
# axes[0,0].set_yticklabels(ylabels), axes[0,0].set_ylabel('Resale Price SGD ($)', size=10)
# axes[0,0].set_xlabel('Distance From Commercial Center', size=10), axes[0,1].set_xlabel('Distance From Mrt Station', size=10)
# axes[0,2].set_xlabel('Distance From Primary Schools', size=10), axes[0,3].set_xlabel('Distance From Secondary Schools', size=10)
# axes[0,4].set_xlabel('Distance From Shops', size=10),
# plt.suptitle('Resale Price (Median of Each Town) VS Distance from Nearest Amenities (Median of Each Town)')
# plt.tight_layout(pad=0, rect=[0, 0, 0.9, 0.9])
# plt.show()

# %% [markdown]
# # Mining

# %% [markdown]
# #### Conforming Test and Train to be the same

# %%
train.describe()
# Out:
#          built_year      num_beds     num_baths     size_sqft  \
# count  18137.000000  18137.000000  18137.000000  1.813700e+04
# mean    2011.458896      2.987374      2.461267  1.580256e+03
# std       15.557238      1.173711      1.270813  1.421397e+04
# min     1963.000000      1.000000      1.000000  6.500000e+01
# 25%     2002.000000      2.000000      2.000000  7.750000e+02
# 50%     2017.000000      3.000000      2.000000  1.076000e+03
# 75%     2023.000000      4.000000      3.000000  1.399000e+03
# max     2028.000000     10.000000     10.000000  1.496000e+06
#
#        available_unit_types  total_num_units         price   cc_distance  \
# count          18137.000000     18137.000000  1.813700e+04  18137.000000
# mean               4.686993       361.881348  2.298242e+06     10.393504
# std                1.665679       297.139575  2.161732e+06      4.684709
# min                1.000000         4.000000  2.508000e+05      0.166654
# 25%                4.000000       158.000000  8.169000e+05      7.080943
# 50%                5.000000       296.000000  1.585400e+06     10.324064
# 75%                6.000000       455.000000  2.927400e+06     13.012952
# max               10.000000      2612.000000  1.667400e+07     29.798731
#
#        mrt_distance  primary_school_distance  secondary_school_distance  \
# count  18137.000000             18137.000000               18137.000000
# mean       8.756814                11.061377                   9.643028
# std        4.541275                 5.208995                   4.306314
# min        0.027288                 0.163496                   0.269643
# 25%        5.085190                 7.165982                   6.176892
# 50%        8.305459                10.932052                   9.546461
# 75%       12.260248                14.821674                  13.163937
# max       22.877877                29.078982                  20.994975
#
#        shop_distance    population     area_size
# count   18137.000000  18137.000000  18137.000000
# mean        9.643028  17094.232232      1.796510
# std         4.306314  16241.571242      1.530318
# min         0.269643      0.000000      0.436400
# 25%         6.176892   5340.000000      1.061900
# 50%         9.546461  10840.000000      1.432900
# 75%        13.163937  24760.000000      2.206800
# max        20.994975  60670.000000      8.405500

# %%
X_train = train.drop(columns=['price','subzone'])
y_train = train['price']

X_test = test.drop(columns='subzone')

# %%
#Regression Task
X_train = pd.get_dummies(X_train)

# %%
X_test = pd.get_dummies(X_test)

# %%
X_train.count()
# Out:
# built_year                 18137
# num_beds                   18137
# num_baths                  18137
# size_sqft                  18137
# available_unit_types       18137
#                            ...
# planning_area_tanglin      18137
# planning_area_tengah       18137
# planning_area_toa payoh    18137
# planning_area_woodlands    18137
# planning_area_yishun       18137
# Length: 82, dtype: int64

# %%
X_test.count()
# Out:
# built_year                 6966
# num_beds                   6966
# num_baths                  6966
# size_sqft                  6966
# available_unit_types       6966
#                            ...
# planning_area_tanglin      6966
# planning_area_tengah       6966
# planning_area_toa payoh    6966
# planning_area_woodlands    6966
# planning_area_yishun       6966
# Length: 82, dtype: int64

# %% [markdown]
# #### Parameter Optimization before Stacking

# %%
num_selector = make_column_selector(dtype_include = np.float64)

# %%
num_transformer = Pipeline([('add_interaction', PolynomialFeatures( interaction_only = True, include_bias = False)),
                            ('scaler', StandardScaler()  )])

# %%
preprocessor = ColumnTransformer([('num', num_transformer, num_selector)])
preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('add_interaction',
#                                                   PolynomialFeatures(include_bias=False,
#                                                                      interaction_only=True)),
#                                                  ('scaler', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x13d95a7f0>)])

# %%
pipe_LGB = Pipeline([('preprocessor', preprocessor), 
                     ('regressor', lgb.LGBMRegressor(metric = 'mean_squared_error', 
                                                    random_state = 0))])

param_grid = {'preprocessor__num__scaler': [StandardScaler(), MinMaxScaler(), RobustScaler(),MaxAbsScaler()], 
              'regressor__n_estimators': list(range(20,50,10)),
              'regressor__learning_rate': [0.01,0.05, 0.1],
              'regressor__max_depth': list(range(1,4,1)),
              'regressor__num_leaves': list(range(10,20,5)),
              'regressor__boosting_type': ['gbdt', 'rf']
}

#note that n_jobs parameter is important to let the function know to utilize parallel processing. else it will just use one core.
grid_LGB = GridSearchCV(pipe_LGB, param_grid, cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=2, random_state=2022), scoring = 'average_precision', verbose = 2, n_jobs=-1) 


grid_LGB.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 432 candidates, totalling 4320 fits
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=10; total time=   0.4s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=10; total time=   0.5s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=10; total time=   0.5s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=10; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=15; total time=   0.4s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=15; total time=   0.4s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=15; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=20, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=10; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=10; total time=   0.5s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=10; total time=   0.5s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=10; total time=   0.5s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.4s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.4s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.5s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.5s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 352, in _score
#     raise ValueError("{0} format is not supported".format(y_type))
# ValueError: multiclass format is not supported
#
#   warnings.warn(
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=StandardScaler(), regressor__boosting_type=gbdt, regressor__learning_rate=0.01, regressor__max_depth=1, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.5s
# ...
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.3s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.3s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.3s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.3s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.3s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=30, regressor__num_leaves=15; total time=   0.3s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.3s
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.4s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.5s
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.4s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.4s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.5s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.4s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.4s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=10; total time=   0.3s
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=15; total time=   0.4s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=15; total time=   0.5s
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 2160 fits failed out of a total of 4320.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2160 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.9/site-packages/lightgbm/sklearn.py", line 895, in fit
#     super().fit(X, y, sample_weight=sample_weight, init_score=init_score,
#   File "/usr/local/lib/python3.9/site-packages/lightgbm/sklearn.py", line 748, in fit
#     self._Booster = train(
#   File "/usr/local/lib/python3.9/site-packages/lightgbm/engine.py", line 271, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/usr/local/lib/python3.9/site-packages/lightgbm/basic.py", line 2610, in __init__
#     _safe_call(_LIB.LGBM_BoosterCreate(
#   File "/usr/local/lib/python3.9/site-packages/lightgbm/basic.py", line 125, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode('utf-8'))
# lightgbm.basic.LightGBMError: Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /Users/runner/work/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=15; total time=   0.5s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=15; total time=   0.3s
# [CV] END preprocessor__num__scaler=MaxAbsScaler(), regressor__boosting_type=rf, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=40, regressor__num_leaves=15; total time=   0.3s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=2, n_splits=5, random_state=2022),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('add_interaction',
#                                                                                           PolynomialFeatures(include_bias=False,
#                                                                                                              interaction_only=True)),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          <sklearn.compose._column_transformer.make_column_selector obj...
#                                                       random_state=0))]),
#              n_jobs=-1,
#              param_grid={'preprocessor__num__scaler': [StandardScaler(),
#                                                        MinMaxScaler(),
#                                                        RobustScaler(),
#                                                        MaxAbsScaler()],
#                          'regressor__boosting_type': ['gbdt', 'rf'],
#                          'regressor__learning_rate': [0.01, 0.05, 0.1],
#                          'regressor__max_depth': [1, 2, 3],
#                          'regressor__n_estimators': [20, 30, 40],
#                          'regressor__num_leaves': [10, 15]},
#              scoring='average_precision', verbose=2)

# %%
grid_LGB.best_params_
# Out:
# {'preprocessor__num__scaler': StandardScaler(),
#  'regressor__boosting_type': 'gbdt',
#  'regressor__learning_rate': 0.01,
#  'regressor__max_depth': 1,
#  'regressor__n_estimators': 50,
#  'regressor__num_leaves': 21}

# %%
final_model = grid_LGB.best_estimator_
final_model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('add_interaction',
#                                                                    PolynomialFeatures(include_bias=False,
#                                                                                       interaction_only=True)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x13db780a0>)])),
#                 ('regressor',
#                  LGBMRegressor(learning_rate=0.01, max_depth=1,
#                                metric='mean_squared_error', n_estimators=20,
#                                num_leaves=10, random_state=0))])

# %% [markdown]
# # Predict

# %%
predictions_df=pd.DataFrame(data={"Predicted":final_model.predict(X_test)})

# %%
#export as csv
predictions_df.to_csv('pred.csv', index_label = 'Id')
